# %%
import numpy as np
import tifffile as tiff

import matplotlib.pyplot as plt

# %%
img = tiff.imread("data/H&E/Project_BLOCCO_1_ch00.tif")
cellpose = tiff.imread("data/CellPose/Project_BLOCCO_1_ch00.tif")
cellpose2 = tiff.imread("diff/Project_BLOCCO_1_ch00_masks.tif")

# %%
img[cellpose > 0] = 255
img[cellpose2 > 0] = 255

# %%
plt.imshow(img[::16, ::16])

# %%
tiff.imwrite("diff/Project_BLOCCO_1_ch00_2.tif", img)
